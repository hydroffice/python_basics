# %% [markdown]
# <a href="https://www.hydroffice.org/epom/"><img src="images/000_000_epom_logo.png" alt="ePOM" title="Open ePOM home page" align="center" width="15%" alt="Python logo\"></a>

# %% [markdown]
# <img align="center" width="75%" style="padding-right:10px; padding-top:10px;" src="images/congrats.png">

# %% [markdown]
# You reached the end of **Programming Basics with Python**.

# %% [markdown]
# ## What's Next?

# %% [markdown]
# A number of resources are listed in the *Useful References* section of each notebook. It is surely a good idea to familiarize more with Python using them!

# %% [markdown]
# Another good idea may be to go through the whole collection of notebooks one more time, just before your first arrival at UNH CCOM/JHC.

# %% [markdown]
# You will be called to apply the notions presented in these notebooks during the orientation week. That is, you will receive a review notebook with exercises similar to the ones presents in this collection.

# %% [markdown]
# **See you soon in Durham!**

# %% [markdown]
# <!--NAVIGATION-->
# [< Wrapping Up Notions](010_Wrapping_Up_Notions.ipynb) | [Contents](index.ipynb) |
