# %% [markdown]
# <a href="https://www.hydroffice.org/epom/"><img src="images/000_000_epom_logo.png" alt="ePOM" title="Open ePOM home page" align="center" width="12%" alt="Python logo\"></a>

# %% [markdown]
# # Wrapping Up Notions

# %% [markdown]
# <img align="left" width="6%" style="padding-right:10px;" src="images/arrow.png">
#
# A key concept.

# %% [markdown]
# <img align="left" width="6%" style="padding-right:10px;" src="images/test.png">
#
# Write code that ...

# %%
x = 0

# %% [markdown]
# ***

# %% [markdown]
# <img align="left" width="6%" style="padding-right:10px; padding-top:10px;" src="images/refs.png">
#
# ## Useful References

# %% [markdown]
# * [The official Python 3.6 documentation](https://docs.python.org/3.6/index.html)

# %% [markdown]
# <img align="left" width="5%" style="padding-right:10px;" src="images/email.png">
#
# *For issues or suggestions related to this notebook, write to: gmasetti@ccom.unh.edu*

# %% [markdown]
# <!--NAVIGATION-->
# [< More About Classes](009_More_About_Classes.ipynb) | [Contents](index.ipynb) | [Congrats >](congrats.ipynb)
